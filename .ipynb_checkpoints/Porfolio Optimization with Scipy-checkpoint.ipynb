# %% [markdown]
# # Portfolio Optimization with Scipy
# This is an example of how to use **scipy.optimize.minimize** to perform portfolio optimization.  The problem we are trying to solve with Portfolio Optimization is how to determine the optimum asset mix to optimize certai portfolio objectives
#
# *  Minimize Volitility
# *  Maximize Returns
# *  Maximize the Portfolio's Sharpe Ratio
#
#
# ## A. Calculate Earnings for Assests in Portfolio
#
# Create list of tickers symbols of assets in the portfolio to optimize.  Also, define the **start** date and **end** date to pull.

# %%
import datetime

tickers = sorted(['NVDA','SOXL','PSI','MBLY'])

start = datetime.datetime(2016, 1, 1)
#start = datetime.datetime.today() - datetime.timedelta(days=365)
end = datetime.datetime.today()

# %% [markdown]
# ### Download Daily Data
# We will use **pandas_datareader** to download the daily **Adjusted Close** price of the assets in the porfolio from Google.

# %%
import pandas as pd
import pandas_datareader.data as web

TICKER_DATA = web.DataReader(tickers, 'yahoo', start) #, end)
TICKER_DATA.Close.tail()

# %% [markdown]
# ### Calculate Daily Assets Returns
# Determine the percent change from one day to the next, as daily return, and save it to the **RETURNS** data frame.
#
# $$ \hbox{Expected Returns} = \frac{Close - Close_{-1} }{Close_{-1} } $$

# %%
RETURNS = TICKER_DATA['Close'].pct_change()[1:]
RETURNS.tail()
# Out:
#                 MBLY      NVDA       PSI      SOXL
# Date
# 2017-06-21  0.001918  0.015151  0.007795  0.034039
# 2017-06-22  0.001755 -0.006898 -0.004777 -0.007491
# 2017-06-23  0.002708 -0.028667  0.005714  0.009248
# 2017-06-26  0.000635 -0.010921 -0.009318 -0.024858
# 2017-06-27 -0.000635 -0.036609 -0.029135 -0.080795

# %% [markdown]
# ### Calculate the average daily returns
# For each asset in the portfolio, we need to determine the average returns by calculating the mean of the observed days.

# %%
EXPECTED_RETURNS = RETURNS.mean()
EXPECTED_RETURNS
# Out:
# MBLY    0.001642
# NVDA    0.004464
# PSI     0.001535
# SOXL    0.004002
# dtype: float64

# %% [markdown]
# These returns can be annualized by $$ (( Daily Returns + 1)^{365} - 1) * 100% $$

# %%
((EXPECTED_RETURNS + 1)**365 -1)*100
# Out:
# MBLY     82.010047
# NVDA    408.268818
# PSI      75.022369
# SOXL    329.667891
# dtype: float64

# %% [markdown]
# ### Calculate the covariance matrix of the returns
# The variance/covariance matrix provides a measure of volatility for the assets (and between assets) in the portfolio.

# %%
COVARIANCE = RETURNS.cov()
COVARIANCE
# Out:
#           MBLY      NVDA       PSI      SOXL
# MBLY  0.000879  0.000144  0.000129  0.000357
# NVDA  0.000144  0.000866  0.000238  0.000725
# PSI   0.000129  0.000238  0.000188  0.000524
# SOXL  0.000357  0.000725  0.000524  0.001583

# %% [markdown]
# ### Define the Risk Free Rate
# We will use the expected daily returns of the **S&P 500**

# %%
RISK_FREE_RATE = web.DataReader('IND', 'google', start).pct_change()[1:].Close.mean() # Risk Free Asset Expected returns
RISK_FREE_RATE
# Out:
# 0.001339153407485635

# %% [markdown]
# ## B. Create a coupe of utility functions
#
#
# Define a function (**RANDOM_PORTFOLIO_WEIGHTS**) to generate a random mixed portfolio and a function (**PORTFOLIO**) to calculate the portfolio's **mean returns** ($\mu = w * p^T$) and **standard deviation** ($\sigma = \sqrt{w^T * C * w}$).  Where $w$ is a **vector of asset weights** and $C$ is a **covariance matrix**.

# %%
import numpy as np

def RANDOM_PORTFOLIO_WEIGHTS(ticker_count):
    ''' 
    Create a portfolio mix without shorts
    '''
    
    w = np.random.rand(ticker_count)
    # return 1 - 2 * w / sum(w)
    return w / sum(w)



def PORTFOLIO( weights ):
    ''' 
    Calculates and returns the portfolio 
        Avgerage Daily Returns (mu),  
        Standard deviation of the Daily Returns (sigma), and
        Sharpe Ratio
    '''

    p = np.asmatrix(EXPECTED_RETURNS)
    w = np.asmatrix(weights)
    C = np.asmatrix(COVARIANCE)
    
    mu = w * p.T
    sigma = np.sqrt(w * C * w.T)
    sharpe = (mu - RISK_FREE_RATE)/sigma
    annualized_returns = ((mu[0,0] + 1)**365 - 1) * 100
    
    return [mu[0,0], sigma[0,0], sharpe[0,0], annualized_returns]

# %% [markdown]
# Generate a set of **n_portfolios** portfolios, with random mixed parts of the assets in **tickers**, and use the **PORTFOLIO** function to obtain *Expected Daily Returns*, *Standard Deviation* of the Daily Returns, and the portfolio's *Sharpe ratio*.

# %%
n_portfolios = 21000
means, stds, sharpe, annu_returns = np.column_stack([
    PORTFOLIO( RANDOM_PORTFOLIO_WEIGHTS(len(tickers)) ) 
    for _ in range(n_portfolios)
])

# %% [markdown]
# ### Plot the Markowitz Bullet of Random Mixed Weights Portfolios
#
# Use the expected returns and volatility of the random portfolios to draw the Markowitz Bullet of the porfolios.

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()

p = figure( title = 'Markowitz Bullet for set of Random Portfolios' , plot_width=980 )
p.xaxis.axis_label = 'Volatility'
p.yaxis.axis_label = 'Daily Returns'
p.toolbar.active_drag = None
p.circle(x=stds, y=means, fill_alpha=0.2, size=2 )

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="41d9c557-278e-47ec-904e-59ffd2be8fb5">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="662898cd-2e9f-4a3d-af0d-9216e9c08fc0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("662898cd-2e9f-4a3d-af0d-9216e9c08fc0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("662898cd-2e9f-4a3d-af0d-9216e9c08fc0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '662898cd-2e9f-4a3d-af0d-9216e9c08fc0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"91c21295-3299-4e3f-8fa6-e7fbc2210d5f":{"roots":{"references":[{"attributes":{"plot":{"id":"f85fa6bb-449a-432a-b451-3f5c7631b033","subtype":"Figure","type":"Plot"}},"id":"0ce132b6-d29e-4532-9ec9-96a9934082d4","type":"WheelZoomTool"},{"attributes":{},"id":"d61df77f-43c0-4e98-8bd5-3a70962eb8a2","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"f85fa6bb-449a-432a-b451-3f5c7631b033","subtype":"Figure","type":"Plot"}},"id":"d741848b-eddb-4e98-9944-3172f5f0006b","type":"PanTool"},{"attributes":{"axis_label":"Daily Returns","formatter":{"id":"182b0a58-444e-4d7b-90cc-d883d39ddfaa","type":"BasicTickFormatter"},"plot":{"id":"f85fa6bb-449a-432a-b451-3f5c7631b033","subtype":"Figure","type":"Plot"},"ticker":{"id":"cc16416e-493d-4fb4-85c3-6589a424149d","type":"BasicTicker"}},"id":"219bd238-536f-452d-8196-3a6076707e19","type":"LinearAxis"},{"attributes":{},"id":"02b854a3-5657-473e-acea-e77c1fd5aaf0","type":"ToolEvents"},{"attributes":{"callback":null},"id":"b337e76a-43da-4579-bf1b-10fc93f77927","type":"DataRange1d"},{"attributes":{"axis_label":"Volatility","formatter":{"id":"d61df77f-43c0-4e98-8bd5-3a70962eb8a2","type":"BasicTickFormatter"},"plot":{"id":"f85fa6bb-449a-432a-b451-3f5c7631b033","subtype":"Figure","type":"Plot"},"ticker":{"id":"4c1b2e23-c184-437e-9c94-8f9300b32b3a","type":"BasicTicker"}},"id":"83181e13-f2f4-4472-bf52-fbb4ba65649f","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"52f02186-16d0-4279-8c81-62d220c4d730","type":"Circle"},{"attributes":{"callback":null},"id":"39a09a8c-8c7c-41c8-80e1-049dad4a8bcc","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"7f35ec10-d9d7-4bc8-99e3-c4cbe5a41ddb","type":"Circle"},{"attributes":{"below":[{"id":"83181e13-f2f4-4472-bf52-fbb4ba65649f","type":"LinearAxis"}],"left":[{"id":"219bd238-536f-452d-8196-3a6076707e19","type":"LinearAxis"}],"plot_width":980,"renderers":[{"id":"83181e13-f2f4-4472-bf52-fbb4ba65649f","type":"LinearAxis"},{"id":"8986acdc-05e7-486d-bb6d-2b7e672716cc","type":"Grid"},{"id":"219bd238-536f-452d-8196-3a6076707e19","type":"LinearAxis"},{"id":"1a73c84b-c514-4719-a378-374ef87e9a88","type":"Grid"},{"id":"56ea6db7-72d3-424a-9c1f-e7e5c851c9be","type":"BoxAnnotation"},{"id":"be610cf6-23f5-4608-9f4b-b0b2f2dc3d3a","type":"GlyphRenderer"}],"title":{"id":"b0b2b886-a909-4707-8a3d-e5729628be4d","type":"Title"},"tool_events":{"id":"02b854a3-5657-473e-acea-e77c1fd5aaf0","type":"ToolEvents"},"toolbar":{"id":"34f29d62-c233-4b95-8344-f8d702779788","type":"Toolbar"},"x_range":{"id":"39a09a8c-8c7c-41c8-80e1-049dad4a8bcc","type":"DataRange1d"},"y_range":{"id":"b337e76a-43da-4579-bf1b-10fc93f77927","type":"DataRange1d"}},"id":"f85fa6bb-449a-432a-b451-3f5c7631b033","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"4c1b2e23-c184-437e-9c94-8f9300b32b3a","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"56ea6db7-72d3-424a-9c1f-e7e5c851c9be","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[21000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[21000]}}},"id":"ddd8a7f2-7f5e-4860-a616-c8461e77db36","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"f85fa6bb-449a-432a-b451-3f5c7631b033","subtype":"Figure","type":"Plot"}},"id":"9432ad4b-a2e8-43c5-b0d9-4e8bb360a4ea","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"f85fa ...

# %% [markdown]
# ## D. Find the Minimum Volatility Portfolio

# %% [markdown]
# The **Scipy minimize** function will need a function with one objective (Variance).  The **getVolatility** function wraps the **PORTFOLIO** function and only returns the expected variance.

# %%
def getVolatility(mix):
    return( PORTFOLIO(mix)[1] )

# %%
from scipy.optimize import minimize

x0 = np.ones(len(tickers)) 


cons = ({'type': 'eq', 'fun': lambda x:  sum(x) - 1})  # MIX SHOULD ADD TO ONE i.e. 'sum(x) = 1' -> 'sum(x) - 1 = 0'


bnds = tuple((0.0, 1.0) for x in x0)  # NO SHORT... ALL VALUES POSITIVE BETWEEN 0 AND 1
#bnds = tuple((-1.0, 1.0) for x in x0)  # ALLOW SHORT... ALL VALUES POSITIVE BETWEEN 0 AND 1

OPT_VOLATILITY = minimize(getVolatility, x0, method='SLSQP', bounds=bnds, constraints=cons, options={'disp': True, 'ftol': 1e-8})


print( "Lowest Daily Volatility {}".format( np.round(OPT_VOLATILITY.fun, 4) ) )
OPT_VOLATILITY_MIX = pd.DataFrame(np.round( OPT_VOLATILITY.x * 100, 2 ), index=RETURNS.columns, columns=['Percent of Portfolio'])
OPT_VOLATILITY_MIX
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.013553459513938378
#             Iterations: 12
#             Function evaluations: 72
#             Gradient evaluations: 12
# Lowest Daily Volatility 0.0136
#       Percent of Portfolio
# MBLY                  7.31
# NVDA                  0.00
# PSI                  92.69
# SOXL                  0.00

# %%
min_volatility_mean , min_volatility_std , min_volatility_sharpe , min_volatility_annualized = PORTFOLIO( OPT_VOLATILITY.x ) 
print( 'Markowitz Bullet for Portfolio with the minimum volatility of {1}, daily returns of {0}, and Sharpe ratio of {2}'.\
           format(np.round(min_volatility_mean,4) , np.round(min_volatility_std,4) , np.round(min_volatility_sharpe,4) ) )
# Out:
# Markowitz Bullet for Portfolio with the minimum volatility of 0.0136, daily returns of 0.0015, and Sharpe ratio of 0.015

# %%
p = figure( title = 'Markowitz Bullet for Portfolio with the minimum volatility of {1}, annualized returns of {0}%, and Sharpe ratio of {2}'.\
           format(np.round(min_volatility_annualized,2) , np.round(min_volatility_std,4) , np.round(min_volatility_sharpe,4) ) , 
           plot_width=980  )
p.xaxis.axis_label = 'Volatility'
p.yaxis.axis_label = 'Daily Returns' 
 
p.circle(x=stds, y=means, fill_alpha=0.2, size=2 )
p.circle(x=min_volatility_std, y=min_volatility_mean, fill_alpha=0.77 , size=14 , color='red' )
p.toolbar.active_drag = None
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="514fdc68-cdae-4605-9311-5a5b9e6eefd2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("514fdc68-cdae-4605-9311-5a5b9e6eefd2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("514fdc68-cdae-4605-9311-5a5b9e6eefd2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '514fdc68-cdae-4605-9311-5a5b9e6eefd2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a4dd2cf7-f9f2-427b-9906-525788f950e0":{"roots":{"references":[{"attributes":{"axis_label":"Daily Returns","formatter":{"id":"ed579acf-6b13-4c85-a424-ce9877d99a98","type":"BasicTickFormatter"},"plot":{"id":"f987a933-effa-42c8-bea8-f3f25794451a","subtype":"Figure","type":"Plot"},"ticker":{"id":"c6c82564-4e57-4767-a953-70caac7caac6","type":"BasicTicker"}},"id":"87024268-8500-4b32-8580-366f8a35d945","type":"LinearAxis"},{"attributes":{},"id":"c6c82564-4e57-4767-a953-70caac7caac6","type":"BasicTicker"},{"attributes":{"callback":null,"data":{}},"id":"c4d7868b-d6de-4bb0-b362-13be54e73e43","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"1d243719-4500-4360-a709-9c569858d366","type":"DataRange1d"},{"attributes":{"overlay":{"id":"503a01f4-26da-48a7-a59a-980396e02de3","type":"BoxAnnotation"},"plot":{"id":"f987a933-effa-42c8-bea8-f3f25794451a","subtype":"Figure","type":"Plot"}},"id":"71e45a6d-4f36-4135-b265-172263579f3e","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":"Markowitz Bullet for Portfolio with the minimum volatility of 0.0136, annualized returns of 75.52%, and Sharpe ratio of 0.015"},"id":"2ba0265d-d37a-49f8-a749-5d0ae41f3ed5","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"503a01f4-26da-48a7-a59a-980396e02de3","type":"BoxAnnotation"},{"attributes":{},"id":"46782ba9-ed0e-4cd7-834d-ab20a8dbd065","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"f987a933-effa-42c8-bea8-f3f25794451a","subtype":"Figure","type":"Plot"},"ticker":{"id":"c6c82564-4e57-4767-a953-70caac7caac6","type":"BasicTicker"}},"id":"650300c8-c3a7-43d9-9d1c-06d8972f9757","type":"Grid"},{"attributes":{},"id":"927b6be6-4287-4e19-9f6f-457c255a749c","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Volatility","formatter":{"id":"927b6be6-4287-4e19-9f6f-457c255a749c","type":"BasicTickFormatter"},"plot":{"id":"f987a933-effa-42c8-bea8-f3f25794451a","subtype":"Figure","type":"Plot"},"ticker":{"id":"9d96ff93-d07f-4f15-be04-45ccb515252c","type":"BasicTicker"}},"id":"c5554c26-f682-47de-8214-f292081f071d","type":"LinearAxis"},{"attributes":{"plot":{"id":"f987a933-effa-42c8-bea8-f3f25794451a","subtype":"Figure","type":"Plot"}},"id":"c706c900-252c-4ebd-b797-916d5538e600","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"c4d7868b-d6de-4bb0-b362-13be54e73e43","type":"ColumnDataSource"},"glyph":{"id":"66d92dc1-d486-4c27-918b-96f270cd05fb","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"fb35aa83-0697-4fcc-aacc-21a654487dcd","type":"Circle"},"selection_glyph":null},"id":"03bcc623-fd91-4f53-bb5d-ad4ba379e5c0","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"f987a933-effa-42c8-bea8-f3f25794451a","subtype":"Figure","type":"Plot"}},"id":"b5137301-2d48-4bc2-b630-ae4c565d96a5","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"133b863b-1627-406f-8d33-f224a8de838a","type":"Circle"},{"attributes":{"active_drag":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"b5137301-2d48-4bc2-b630-ae4c565d96a5","type":"PanTool"},{"id":"c706c900-252c-4ebd-b797-916d5538e600","type":"WheelZoomTool"},{"id":"71e45a6d-4f36-4135-b265-172263579f3e","type":"BoxZoomTool"},{"id":"a16223a7-9941-4520-b75f-ebaf1bd23a0f","type":"SaveTool"},{"id":"973e23fd-8d17-4ceb-a6e2-a63bebfc96fc","type":"ResetTool"},{"id":"b8be3ae5-ad90-48d3-b18f-1468ff3e6b03","type":"HelpTool"}]},"id":"41181d89-426d-423c-8fd7-3344fd2e9c3d","type":"Toolbar"},{"attributes":{"plot":{"id":"f987a933-effa-42c8-bea8-f3f25794451a","subtype":"Figure","type":"Plot"},"ticker":{"id":"9d ...

# %% [markdown]
# ## E. Efficient Portfolio for the highest daily returns

# %%
def getReturns(mix):
    return( -PORTFOLIO(mix)[0] )

# %%
from scipy.optimize import minimize

x0 = np.ones(len(tickers))  


cons = ({'type': 'eq', 'fun': lambda x:  sum(x) - 1})  # MIX SHOULD ADD TO ONE i.e. 'sum(x) = 1' -> 'sum(x) - 1 = 0'


bnds = tuple((0.0, 1.0) for x in x0)  # NO SHORT... ALL VALUES POSITIVE BETWEEN 0 AND 1
#bnds = tuple((-1.0, 1.0) for x in x0)  # ALLOW SHORT... ALL VALUES BETWEEN -1 AND 1

OPT_RETURNS = minimize(getReturns, x0, method='SLSQP', bounds=bnds, constraints=cons, options={'disp': True, 'ftol': 1e-8})


print( "Highest Daily Returns {}".format( np.round(-OPT_RETURNS.fun, 4) ) )
OPT_RETURNS_MIX = pd.DataFrame(np.round( OPT_RETURNS.x * 100, 2 ), index=RETURNS.columns, columns=['Percent of Portfolio'])
OPT_RETURNS_MIX
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -0.004464292357527253
#             Iterations: 15
#             Function evaluations: 90
#             Gradient evaluations: 15
# Highest Daily Returns 0.0045
#       Percent of Portfolio
# MBLY                   0.0
# NVDA                 100.0
# PSI                    0.0
# SOXL                   0.0

# %%
target_return_mean , target_return_std , target_return_sharpe , target_return_annualized = PORTFOLIO( OPT_RETURNS.x ) 
print( 'Markowitz Bullet for Portfolio with maximum daily returns of {0}, sigma of {1}, and Sharpe ratio {2}'.\
           format(np.round(target_return_mean,4) , np.round(target_return_std,4) , np.round(target_return_sharpe,5) ) )
# Out:
# Markowitz Bullet for Portfolio with maximum daily returns of 0.0045, sigma of 0.0294, and Sharpe ratio 0.10622

# %%
p = figure( title = 'Markowitz Bullet for Portfolio with maximum annual returns of {0}%, sigma of {1}, and Sharpe ratio {2}'.\
           format(np.round(target_return_annualized,2) , np.round(target_return_std,4) , np.round(target_return_sharpe,4) ) , 
           plot_width=980  )
p.xaxis.axis_label = 'Volatility'
p.yaxis.axis_label = 'Daily Returns'
 
p.circle(x=stds, y=means, fill_alpha=0.2, size=2 )
p.circle(x=target_return_std, y=target_return_mean, fill_alpha=0.77 , size=14 , color='red' )
p.toolbar.active_drag = None
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a09d4c6a-c3ec-4141-b302-e7b9b9d7d5f7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a09d4c6a-c3ec-4141-b302-e7b9b9d7d5f7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a09d4c6a-c3ec-4141-b302-e7b9b9d7d5f7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a09d4c6a-c3ec-4141-b302-e7b9b9d7d5f7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"32b322cc-ca51-48f8-b6e8-525460deef7a":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"49ba05dc-6f2f-41f7-8ae2-78fecc990c2b","type":"Circle"},{"attributes":{},"id":"2768283e-7330-4ac6-8ea2-9de48e096a95","type":"BasicTickFormatter"},{"attributes":{},"id":"0de622ed-debe-49a9-8b3a-5127e50aafa5","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.77},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":14},"x":{"value":0.029421042693452495},"y":{"value":0.004464292357527253}},"id":"a5b45174-6c1a-4ce3-95e5-d01b136a9a03","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"1e7f5159-b1d2-4f44-8971-4cb8b4288429","subtype":"Figure","type":"Plot"},"ticker":{"id":"770160fc-6986-475f-85e4-dc98d8cca35b","type":"BasicTicker"}},"id":"8731a8a2-9db0-4cab-a5e1-16389e639a19","type":"Grid"},{"attributes":{},"id":"770160fc-6986-475f-85e4-dc98d8cca35b","type":"BasicTicker"},{"attributes":{"plot":{"id":"1e7f5159-b1d2-4f44-8971-4cb8b4288429","subtype":"Figure","type":"Plot"}},"id":"30a07f99-97c8-441e-88a9-b9359e50bbbc","type":"HelpTool"},{"attributes":{"data_source":{"id":"8de25ca2-cc48-4e7d-987d-ec704de43a04","type":"ColumnDataSource"},"glyph":{"id":"0632787a-d732-48ba-b97f-c3735bf1e288","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"49ba05dc-6f2f-41f7-8ae2-78fecc990c2b","type":"Circle"},"selection_glyph":null},"id":"d635c2a5-c172-4b84-bd38-a620e8ab2380","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":14},"x":{"value":0.029421042693452495},"y":{"value":0.004464292357527253}},"id":"9858160d-b3b7-4702-bc52-e367abbb3e5d","type":"Circle"},{"attributes":{"plot":{"id":"1e7f5159-b1d2-4f44-8971-4cb8b4288429","subtype":"Figure","type":"Plot"}},"id":"2828e2e5-4044-495c-8c93-313d06769f92","type":"PanTool"},{"attributes":{"plot":{"id":"1e7f5159-b1d2-4f44-8971-4cb8b4288429","subtype":"Figure","type":"Plot"}},"id":"165bb442-897e-4989-80a2-e891542e6942","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"be126ce5-1831-4152-859d-4e796e717bd1","type":"ColumnDataSource"},"glyph":{"id":"a5b45174-6c1a-4ce3-95e5-d01b136a9a03","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9858160d-b3b7-4702-bc52-e367abbb3e5d","type":"Circle"},"selection_glyph":null},"id":"5799fa3f-e395-4862-975c-105f5aa40152","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"f2048457-1ad4-43f5-acd9-08db1292040f","type":"DataRange1d"},{"attributes":{"plot":null,"text":"Markowitz Bullet for Portfolio with maximum annual returns of 408.27%, sigma of 0.0294, and Sharpe ratio 0.1062"},"id":"aabbb4de-afdb-4aad-8fca-9a35628cb245","type":"Title"},{"attributes":{"callback":null,"data":{}},"id":"be126ce5-1831-4152-859d-4e796e717bd1","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"1e7f5159-b1d2-4f44-8971-4cb8b4288429","subtype":"Figure","type":"Plot"}},"id":"0b51e62c-4a18-414d-8326-b83264c17889","type":"SaveTool"},{"attributes":{"active_drag":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"2828e2e5-4044-495c-8c93-313d06769f92","type":"PanTool"},{"id":"165bb442-897e-4989-80a2-e891542e6942","type":"WheelZoomTool"},{"id":"abf54027-1781-4c65-8740-f2fcfd8e1d25","type":"BoxZoomTool"},{"id":"0b51e62c-4a18-414d-8326-b83264c17889","type":"SaveTool"},{"id":"13081b22-fccd-4a79-becc-8bab90240fb3","type":"ResetTool"},{"id":"30a07f99-97c8-441e-88a9-b9359e50bbbc","type":"HelpTool"}]},"id":"5b88ccc6-dd1e-485c-8917-4cb467607fbf","type":"Toolbar"},{"attributes":{"axis_label":"Daily Returns","formatter":{"id":"2768283e-7330-4ac6-8ea2-9de48e096a95","type":"BasicTickFormatter"},"plot":{"id":"1e7f5159-b1d2 ...

# %% [markdown]
# ## F. Optimum Sharpe Ratio
#
# http://www.investopedia.com/terms/s/sharperatio.asp

# %% [markdown]
# The **Scipy minimize** function will need a function with one objective (-Sharpe ratio).  The **getSharpe** function wraps the **PORTFOLIO** function and only returns the Sharpe ratio.

# %%
def getSharpe(mix):
    return( -PORTFOLIO(mix)[2] )

# %%
from scipy.optimize import minimize


x0 = np.ones(len(tickers)) 


cons = ({'type': 'eq', 'fun': lambda x:  sum(x) - 1})  # MIX SHOULD ADD TO ONE i.e. 'sum(x) = 1' -> 'sum(x) - 1 = 0'


bnds = tuple((0.0, 1.0) for x in x0)  # NO SHORT... ALL VALUES POSITIVE BETWEEN 0 AND 1
#bnds = tuple((-1.0, 1.0) for x in x0)  # ALLOW SHORT... ALL VALUES POSITIVE BETWEEN 0 AND 1

OPT_SHARPE = minimize(getSharpe, x0, method='SLSQP', bounds=bnds, constraints=cons, options={'disp': True, 'ftol': 1e-8})


print( "Highest Sharpe Ratio {}".format( np.round(-OPT_SHARPE.fun, 4) ) )
OPT_SHARPE_MIX = pd.DataFrame(np.round( OPT_SHARPE.x * 100, 2 ), index=RETURNS.columns, columns=['Percent of Portfolio'])
OPT_SHARPE_MIX
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -0.10623191734901727
#             Iterations: 8
#             Function evaluations: 48
#             Gradient evaluations: 8
# Highest Sharpe Ratio 0.1062
#       Percent of Portfolio
# MBLY                  0.00
# NVDA                 98.68
# PSI                   0.00
# SOXL                  1.32

# %%
best_sharpe_return , best_sharpe_std , best_sharpe , best_sharpe_annualized_return = PORTFOLIO( OPT_SHARPE.x.T ) 
print('Markowitz Bullet for Portfolio with maximum Sharpe ratio of {2}, return of {0}, and sigma of {1}'.\
           format(np.round(best_sharpe_return,4) , np.round(best_sharpe_std,4) , np.round(best_sharpe,4)) )
# Out:
# Markowitz Bullet for Portfolio with maximum Sharpe ratio of 0.1062, return of 0.0045, and sigma of 0.0294

# %%
p = figure( title = 'Markowitz Bullet for Portfolio with maximum Sharpe ratio of {2}, annualized returns of {0}%, and sigma of {1}'.\
           format(np.round(best_sharpe_annualized_return,2) , np.round(best_sharpe_std,4) , np.round(best_sharpe,4) ) , 
           plot_width=980  )
p.xaxis.axis_label = 'Volatility'
p.yaxis.axis_label = 'Daily Returns'
 
p.circle(x=stds, y=means, fill_alpha=0.2, size=2 )
p.circle(x=best_sharpe_std, y=best_sharpe_return, fill_alpha=0.77 , size=14 , color='red' )
p.toolbar.active_drag = None
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9a8d498a-38a7-4138-b5dc-f302d12e9f98"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9a8d498a-38a7-4138-b5dc-f302d12e9f98");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9a8d498a-38a7-4138-b5dc-f302d12e9f98");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9a8d498a-38a7-4138-b5dc-f302d12e9f98' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bd754f63-d6d0-4083-8636-8139f8338dfa":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"93dea34d-fa7c-483c-9968-d4b8f60f2128","type":"Circle"},{"attributes":{"callback":null},"id":"0f786020-bf52-442e-99a3-b49abeda34c2","type":"DataRange1d"},{"attributes":{"callback":null},"id":"98438802-47bb-4b21-9aa9-47b0d43bb44c","type":"DataRange1d"},{"attributes":{"data_source":{"id":"2496a5d2-b571-4875-bd06-f92f9455b5b0","type":"ColumnDataSource"},"glyph":{"id":"413de14c-87df-4960-95e3-45518b75b50c","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"93dea34d-fa7c-483c-9968-d4b8f60f2128","type":"Circle"},"selection_glyph":null},"id":"7559f5d2-916c-4ec2-b41d-3dee5b02d764","type":"GlyphRenderer"},{"attributes":{},"id":"17f8190b-1db2-442b-b833-2190a391578c","type":"BasicTicker"},{"attributes":{"data_source":{"id":"033bbd1d-c813-4cf8-a137-ef07ab7cdad1","type":"ColumnDataSource"},"glyph":{"id":"6c2d9875-a952-4427-8e3d-ab065134995a","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"bffe5cdf-c2c4-41b5-a3d0-00aaf4123199","type":"Circle"},"selection_glyph":null},"id":"7d0738ca-942a-49eb-abcf-94d61647c720","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"413de14c-87df-4960-95e3-45518b75b50c","type":"Circle"},{"attributes":{"plot":{"id":"391c7e3a-ad56-4d20-81b1-4f52912c77bb","subtype":"Figure","type":"Plot"},"ticker":{"id":"576aca17-e9c0-403d-9b4f-0eca7a260a36","type":"BasicTicker"}},"id":"70617e41-2818-436c-8351-6049019cfeb6","type":"Grid"},{"attributes":{"active_drag":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"fd490c75-b43a-489a-963f-938d46be49e7","type":"PanTool"},{"id":"644915a0-bd1b-4e3a-afbf-ac70bfab381c","type":"WheelZoomTool"},{"id":"c2b001d3-4a0b-48bc-9fa3-3673605d461e","type":"BoxZoomTool"},{"id":"6f608be8-f0db-4084-8781-79a41989bb9c","type":"SaveTool"},{"id":"0b49c16f-b606-4ff1-ae15-b5069ad96241","type":"ResetTool"},{"id":"98c2b28e-f74b-4c29-9d76-db7181df63f4","type":"HelpTool"}]},"id":"a491a926-006f-4a08-83f4-04cdf6d229d7","type":"Toolbar"},{"attributes":{},"id":"576aca17-e9c0-403d-9b4f-0eca7a260a36","type":"BasicTicker"},{"attributes":{},"id":"e310d523-649d-46f4-b404-ce40515d72dd","type":"ToolEvents"},{"attributes":{"plot":{"id":"391c7e3a-ad56-4d20-81b1-4f52912c77bb","subtype":"Figure","type":"Plot"}},"id":"6f608be8-f0db-4084-8781-79a41989bb9c","type":"SaveTool"},{"attributes":{},"id":"9329e2f8-0bed-4049-8418-12203aa5f77c","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"391c7e3a-ad56-4d20-81b1-4f52912c77bb","subtype":"Figure","type":"Plot"}},"id":"98c2b28e-f74b-4c29-9d76-db7181df63f4","type":"HelpTool"},{"attributes":{"plot":{"id":"391c7e3a-ad56-4d20-81b1-4f52912c77bb","subtype":"Figure","type":"Plot"}},"id":"644915a0-bd1b-4e3a-afbf-ac70bfab381c","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":"Markowitz Bullet for Portfolio with maximum Sharpe ratio of 0.1062, annualized returns of 407.14%, and sigma of 0.0294"},"id":"aec06d1d-7143-4b12-bcab-ba4dc23f64a1","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6d6db0d4-8394-4407-a441-5b139473d357","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.77},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":14},"x":{"value":0.029360604963471423},"y":{"value":0.004458186767282277}},"id" ...
