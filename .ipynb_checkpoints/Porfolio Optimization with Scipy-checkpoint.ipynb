# %% [markdown]
# # Portfolio Optimization with Scipy
# This is an example of how to use **scipy.optimize.minimize** to perform portfolio optimization.  The problem we are trying to solve with Portfolio Optimization is how to determine the optimum asset mix to optimize certai portfolio objectives
#
# *  Minimize Volitility
# *  Maximize Returns
# *  Maximize the Portfolio's Sharpe Ratio
#
#
# ## A. Calculate Earnings for Assests in Portfolio
#
# Create list of tickers symbols of assets in the portfolio to optimize.  Also, define the **start** date and **end** date to pull.

# %%
import datetime

tickers = sorted(['NVDA','SOXL','SQ','OLED','LRCX','TTD','TTWO','BA'])

start = datetime.datetime(2016, 1, 1)
#start = datetime.datetime.today() - datetime.timedelta(days=365)
end = datetime.datetime.today()

# %% [markdown]
# ### Download Daily Data
# We will use **pandas_datareader** to download the daily **Adjusted Close** price of the assets in the porfolio from Google.

# %%
import pandas as pd
import pandas_datareader.data as web

TICKER_DATA = web.DataReader(tickers, 'google', start) #, end)
TICKER_DATA.Close.tail()
# Out:
#                 BA    LRCX    NVDA   OLED    SOXL     SQ    TTD    TTWO
# Date
# 2017-09-18  253.08  177.31  187.55  136.7  112.71  28.69  60.09  100.82
# 2017-09-19  252.46  177.12  187.35  142.2  113.88  28.56  61.72  102.38
# 2017-09-20  255.46  173.02  185.84  140.1  109.08  28.47  59.81  102.96
# 2017-09-21  256.04  172.28  180.76  136.0  107.75  28.40  59.54  101.72
# 2017-09-22  256.45  176.73  179.00  132.7  109.29  28.75  59.80  102.84

# %% [markdown]
# ### Calculate Daily Assets Returns
# Determine the percent change from one day to the next, as daily return, and save it to the **RETURNS** data frame.
#
# $$ \hbox{Expected Returns} = \frac{Close - Close_{-1} }{Close_{-1} } $$

# %%
RETURNS = TICKER_DATA['Close'].pct_change()[1:]
RETURNS.tail()
# Out:
#                   BA      LRCX      NVDA      OLED      SOXL        SQ  \
# Date
# 2017-09-18  0.016386  0.024973  0.041308  0.035214  0.039664  0.006667
# 2017-09-19 -0.002450 -0.001072 -0.001066  0.040234  0.010381 -0.004531
# 2017-09-20  0.011883 -0.023148 -0.008060 -0.014768 -0.042150 -0.003151
# 2017-09-21  0.002270 -0.004277 -0.027335 -0.029265 -0.012193 -0.002459
# 2017-09-22  0.001601  0.025830 -0.009737 -0.024265  0.014292  0.012324
#
#                  TTD      TTWO
# Date
# 2017-09-18  0.003507  0.004283
# 2017-09-19  0.027126  0.015473
# 2017-09-20 -0.030946  0.005665
# 2017-09-21 -0.004514 -0.012044
# 2017-09-22  0.004367  0.011011

# %% [markdown]
# ### Calculate the average daily returns
# For each asset in the portfolio, we need to determine the average returns by calculating the mean of the observed days.

# %%
EXPECTED_RETURNS = RETURNS.mean()
EXPECTED_RETURNS
# Out:
# BA      0.002767
# LRCX    0.002770
# NVDA    0.004600
# OLED    0.003791
# SOXL    0.004459
# SQ      0.003881
# TTD     0.003853
# TTWO    0.003401
# dtype: float64

# %% [markdown]
# These returns can be annualized by $$ (( Daily Returns + 1)^{365} - 1) * 100% $$

# %%
((EXPECTED_RETURNS + 1)**365 -1)*100
# Out:
# BA      174.131933
# LRCX    174.423334
# NVDA    433.881817
# OLED    297.954269
# SOXL    407.381862
# SQ      311.238099
# TTD     307.053017
# TTWO    245.318458
# dtype: float64

# %% [markdown]
# ### Calculate the covariance matrix of the returns
# The variance/covariance matrix provides a measure of volatility for the assets (and between assets) in the portfolio.

# %%
COVARIANCE = RETURNS.cov()
COVARIANCE
# Out:
#             BA      LRCX      NVDA      OLED      SOXL        SQ       TTD  \
# BA    0.000129  0.000043  0.000018  0.000051  0.000096  0.000034  0.000050
# LRCX  0.000043  0.000259  0.000194  0.000143  0.000431  0.000126  0.000159
# NVDA  0.000018  0.000194  0.001068  0.000327  0.000770  0.000115  0.000201
# OLED  0.000051  0.000143  0.000327  0.000980  0.000436  0.000115  0.000237
# SOXL  0.000096  0.000431  0.000770  0.000436  0.001201  0.000276  0.000382
# SQ    0.000034  0.000126  0.000115  0.000115  0.000276  0.000465  0.000170
# TTD   0.000050  0.000159  0.000201  0.000237  0.000382  0.000170  0.001631
# TTWO  0.000016  0.000099  0.000192  0.000146  0.000293  0.000086  0.000100
#
#           TTWO
# BA    0.000016
# LRCX  0.000099
# NVDA  0.000192
# OLED  0.000146
# SOXL  0.000293
# SQ    0.000086
# TTD   0.000100
# TTWO  0.000346

# %% [markdown]
# ### Define the Risk Free Rate
# We will use the expected daily returns of the **S&P 500**

# %%
RISK_FREE_RATE = web.DataReader('IND', 'google', start).pct_change()[1:].Close.mean() # Risk Free Asset Expected returns
RISK_FREE_RATE
# Out:
# 0.0022845012717571844

# %% [markdown]
# ## B. Create a coupe of utility functions
#
#
# Define a function (**RANDOM_PORTFOLIO_WEIGHTS**) to generate a random mixed portfolio and a function (**PORTFOLIO**) to calculate the portfolio's **mean returns** ($\mu = w * p^T$) and **standard deviation** ($\sigma = \sqrt{w^T * C * w}$).  Where $w$ is a **vector of asset weights** and $C$ is a **covariance matrix**.

# %%
import numpy as np

def RANDOM_PORTFOLIO_WEIGHTS(ticker_count):
    ''' 
    Create a portfolio mix without shorts
    '''
    
    w = np.random.rand(ticker_count)
    # return 1 - 2 * w / sum(w)
    return w / sum(w)



def PORTFOLIO( weights ):
    ''' 
    Calculates and returns the portfolio 
        Avgerage Daily Returns (mu),  
        Standard deviation of the Daily Returns (sigma), and
        Sharpe Ratio
    '''

    p = np.asmatrix(EXPECTED_RETURNS)
    w = np.asmatrix(weights)
    C = np.asmatrix(COVARIANCE)
    
    mu = w * p.T
    sigma = np.sqrt(w * C * w.T)
    sharpe = (mu - RISK_FREE_RATE)/sigma
    annualized_returns = ((mu[0,0] + 1)**365 - 1) * 100
    
    return [mu[0,0], sigma[0,0], sharpe[0,0], annualized_returns]

# %% [markdown]
# Generate a set of **n_portfolios** portfolios, with random mixed parts of the assets in **tickers**, and use the **PORTFOLIO** function to obtain *Expected Daily Returns*, *Standard Deviation* of the Daily Returns, and the portfolio's *Sharpe ratio*.

# %%
n_portfolios = 10000
means, stds, sharpe, annu_returns = np.column_stack([
    PORTFOLIO( RANDOM_PORTFOLIO_WEIGHTS(len(tickers)) ) 
    for _ in range(n_portfolios)
])

# %% [markdown]
# ### Calculate the Efficient Frontier
# The Efficient Frontier is the line of maximum returns as a function of volatility for a mix of assets.
#
# http://www.quantandfinancial.com/2013/07/mean-variance-portfolio-optimization.html

# %%
from scipy.optimize import minimize

# Given risk-free rate, assets returns and covariances, this function calculates
# min-var frontier and returns its [x,y] points in two arrays
def solve_frontier(R, C):
    def fitness(W, r):
        # For given level of return r, find weights which minimizes
        # portfolio variance.
        mean, var, _, _ = PORTFOLIO(W)
        # Big penalty for not meeting stated portfolio return 
        # effectively serves as optimization constraint
        penalty = 10000 * abs(mean-r)       
        return var + penalty
    frontier_mean, frontier_var = [], []
    n = len(R)  # Number of assets in the portfolio
    # Iterate through the range of returns on Y axis
    for r in np.linspace(min(R), max(R), num=50): 
        W = np.ones([n])/n     # start optimization with equal weights
        b_ = [(0,1) for i in range(n)]
        c_ = ({'type':'eq', 'fun': lambda W: sum(W)-1. })
        optimized = minimize(fun=fitness, x0=W, args=r, method='SLSQP', constraints=c_, bounds=b_, options={'ftol': 1e-10})   
        if not optimized.success: 
            raise BaseException(optimized.message)
        # add point to the min-var frontier [x,y] = [optimized.x, r]
        mu, sig, _, _ = PORTFOLIO(optimized.x)
        frontier_mean.append(mu)
        frontier_var.append( sig )
        
    return frontier_mean, frontier_var

# %%
frontier_mean, frontier_var = solve_frontier(EXPECTED_RETURNS, COVARIANCE)

# %% [markdown]
# ### Plot the Markowitz Bullet of Random Mixed Weights Portfolios
#
# Use the expected returns and volatility of the random portfolios to draw the Markowitz Bullet of the porfolios.

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()

p = figure( title = 'Markowitz Bullet for set of Random Portfolios' , plot_width=980 )
p.xaxis.axis_label = 'Volatility'
p.yaxis.axis_label = 'Daily Returns'
p.toolbar.active_drag = None
p.circle(x=stds, y=means, fill_alpha=0.2, size=2 )
p.line(x=frontier_var, y=frontier_mean, line_width=2, color='gold')

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6ff9df75-7914-4c92-867e-43cd90a9d74b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0d35201c-a691-4bf4-9669-e43b6923942b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("0d35201c-a691-4bf4-9669-e43b6923942b");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0d35201c-a691-4bf4-9669-e43b6923942b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0d35201c-a691-4bf4-9669-e43b6923942b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dd0cf28f-b03d-4531-bad1-195491e92bad":{"roots":{"references":[{"attributes":{},"id":"f8cbbbda-b9de-4a5d-b31a-783ba0a0f30c","type":"ResetTool"},{"attributes":{},"id":"25561bec-61fc-4857-8e03-643aef7dfc8b","type":"SaveTool"},{"attributes":{"overlay":{"id":"58098dfa-4615-425a-8033-fac512a736b3","type":"BoxAnnotation"}},"id":"a7a8a326-68f2-4c1d-b6b9-ebbd23a50989","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.011365051197412285,0.009918873756969473,0.009767414168454915,0.00962630900700771,0.009546951695875642,0.00950437206664317,0.009498461035548217,0.009503946674323529,0.009537168929271127,0.009588866862647982,0.009670081193522,0.009773705912017473,0.009886492028254269,0.01004106691007858,0.010199815097816886,0.010393781238589157,0.010617330823576424,0.010863988274540394,0.011133217248293732,0.011425957253034935,0.011761436071154754,0.012087172804068727,0.012420915490619822,0.012787103660778294,0.013161488803086114,0.013546803246965968,0.013946975335786267,0.014363981437454631,0.01478247254659464,0.015215979860252155,0.015656420754672263,0.01610459324751199,0.016562418882457686,0.017025073721268675,0.01750880947611272,0.018035052023399716,0.018600892094669787,0.01918530742565932,0.019822641177077955,0.020555811097823555,0.021376512957078306,0.022304910920879852,0.023315326781781345,0.024409516061668895,0.02557847366788678,0.026822937536951575,0.0281407274402156,0.029495065379181937,0.030907319410461234,0.032682651023485124],"y":[0.002766667611369863,0.0028040743431855973,0.002841481112348007,0.0028788878350759495,0.0029162946103784898,0.0029537013669711713,0.002991108122445518,0.0030285148941069815,0.003065921642508836,0.0031033284126335925,0.003140735144311088,0.0031781419011584593,0.003215548701591469,0.003252955459814938,0.0032903621778957023,0.0033277689406934824,0.00336517572666318,0.0034025824573316633,0.003439989239488617,0.00347739596780163,0.0035148027420422324,0.0035522094744871893,0.0035896162570966585,0.003627023018375128,0.003664429790433441,0.003701836535783957,0.0037392433007170534,0.0037766500357823297,0.003814056825929976,0.0038514635527372738,0.00388887031662702,0.003926277082533229,0.00396368381715866,0.004001090595901744,0.004038497337216924,0.004075904115603373,0.004113310858828461,0.004150717631602271,0.004188124395881538,0.0042255311366713,0.004262937874121222,0.004300344660344488,0.004337751400454986,0.0043751581880524274,0.0044125649018862114,0.004449971682661612,0.004487378447800781,0.004524785218624389,0.004562191954100434,0.004599598738863536]}},"id":"57819d7a-a823-4f34-b9e9-f6e857009718","type":"ColumnDataSource"},{"attributes":{"source":{"id":"57819d7a-a823-4f34-b9e9-f6e857009718","type":"ColumnDataSource"}},"id":"fa59bb23-0a07-480a-adab-b253cfefbbfe","type":"CDSView"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"58098dfa-4615-425a-8033-fac512a736b3","type":"BoxAnnotation"},{"attributes":{},"id":"6516544d-1282-4671-9588-5165d130896c","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Daily Returns","formatter":{"id":"badac59f-76b7-49d1-b671-e0b651b31737","type":"BasicTickFormatter"},"plot":{"id":"c26e57a4-7033-4f89-9c38-326d3f4cfe51","subtype":"Figure","type":"Plot"},"ticker":{"id":"86d54124-7b9a-48d6-970b-09238b62b5d0","type":"BasicTicker"}},"id":"de705873-b577-4a82-ac20-37d8883b532d","type":"LinearAxis"},{"attributes":{"data_source":{"id":"57819d7a-a823-4f34-b9e9-f6e857009718","type":"ColumnDataSource"},"glyph":{"id":"ff8a2d49-9c26-42e1-a9c8-3cc68d3cde23","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d84fd530-8416-4e47-8c5c-483fd88378bf","type":"Line"},"selection_glyph":null,"view":{"id":"fa59bb23-0a07-480a- ...

# %% [markdown]
# ## D. Find the Minimum Volatility Portfolio

# %% [markdown]
# The **Scipy minimize** function will need a function with one objective (Variance).  The **getVolatility** function wraps the **PORTFOLIO** function and only returns the expected variance.

# %%
def getVolatility(mix):
    return( PORTFOLIO(mix)[1] )

# %%
x0 = np.ones(len(tickers)) 


cons = ({'type': 'eq', 'fun': lambda x:  sum(x) - 1})  # MIX SHOULD ADD TO ONE i.e. 'sum(x) = 1' -> 'sum(x) - 1 = 0'


bnds = tuple((0.0, 1.0) for x in x0)  # NO SHORT... ALL VALUES POSITIVE BETWEEN 0 AND 1
#bnds = tuple((-1.0, 1.0) for x in x0)  # ALLOW SHORT... ALL VALUES POSITIVE BETWEEN 0 AND 1

OPT_VOLATILITY = minimize(getVolatility, x0, method='SLSQP', bounds=bnds, constraints=cons, options={'disp': True, 'ftol': 1e-7})


print( "Lowest Daily Volatility {}".format( np.round(OPT_VOLATILITY.fun, 4) ) )
OPT_VOLATILITY_MIX = pd.DataFrame(np.round( OPT_VOLATILITY.x * 100, 2 ), index=RETURNS.columns, columns=['Percent of Portfolio'])
OPT_VOLATILITY_MIX
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0094782511273276
#             Iterations: 26
#             Function evaluations: 260
#             Gradient evaluations: 26
# Lowest Daily Volatility 0.0095
#       Percent of Portfolio
# BA                   60.68
# LRCX                 13.20
# NVDA                  0.93
# OLED                  0.36
# SOXL                  0.00
# SQ                    7.84
# TTD                   0.28
# TTWO                 16.70

# %%
min_volatility_mean , min_volatility_std , min_volatility_sharpe , min_volatility_annualized = PORTFOLIO( OPT_VOLATILITY.x ) 
print( 'Markowitz Bullet for Portfolio with the minimum volatility of {1}, daily returns of {0}, and Sharpe ratio of {2}'.\
           format(np.round(min_volatility_mean,4) , np.round(min_volatility_std,4) , np.round(min_volatility_sharpe,4) ) )
# Out:
# Markowitz Bullet for Portfolio with the minimum volatility of 0.0095, daily returns of 0.003, and Sharpe ratio of 0.0738

# %%
p = figure( title = 'Markowitz Bullet for Portfolio with the minimum volatility of {1}, annualized returns of {0}%, and Sharpe ratio of {2}'.\
           format(np.round(min_volatility_annualized,2) , np.round(min_volatility_std,4) , np.round(min_volatility_sharpe,4) ) , 
           plot_width=980  )
p.xaxis.axis_label = 'Volatility'
p.yaxis.axis_label = 'Daily Returns' 
 
p.circle(x=stds, y=means, fill_alpha=0.2, size=2 )
p.line(x=frontier_var, y=frontier_mean, line_width=2, color='gold')
p.circle(x=min_volatility_std, y=min_volatility_mean, fill_alpha=0.77 , size=14 , color='red' )
p.toolbar.active_drag = None
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9e5b81e0-af5b-416c-909a-748f285eb627"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("9e5b81e0-af5b-416c-909a-748f285eb627");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9e5b81e0-af5b-416c-909a-748f285eb627");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9e5b81e0-af5b-416c-909a-748f285eb627' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f3c68ceb-315e-4b34-88ed-2bcbdd5f1488":{"roots":{"references":[{"attributes":{},"id":"78e6326d-b0ef-4ad5-a866-05c9cfb2c22e","type":"LinearScale"},{"attributes":{"data_source":{"id":"9aa5d4ed-b067-4c4d-8b85-cead052ccf01","type":"ColumnDataSource"},"glyph":{"id":"02571a89-6e56-46e7-96a1-2a0c7b1cb5f8","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5b4b94e6-2a1b-4207-927b-98a6560c7f95","type":"Circle"},"selection_glyph":null,"view":{"id":"38667bcd-7f15-45aa-bd73-01b8dca846a4","type":"CDSView"}},"id":"fe5a30d4-c331-44cf-8b18-1f1f5488afb0","type":"GlyphRenderer"},{"attributes":{"active_drag":null,"active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b8fe3275-99c8-492c-800c-b3b49715ab49","type":"PanTool"},{"id":"dad87753-01c5-4f57-b3c7-992346a48c5c","type":"WheelZoomTool"},{"id":"5b4c4952-0e60-4fca-b4d8-ebec9845f709","type":"BoxZoomTool"},{"id":"3827de07-964c-4ea3-a44a-5378d4cf9ed2","type":"SaveTool"},{"id":"2d8d9155-dc21-4cca-9b4b-4e135964afdd","type":"ResetTool"},{"id":"0bfb2d25-58b3-4406-9457-014e1756ad78","type":"HelpTool"}]},"id":"516fcfa4-b40c-4cdb-a658-4914d951119d","type":"Toolbar"},{"attributes":{"callback":null},"id":"332f3c23-b811-4286-9c00-c32aa001d091","type":"DataRange1d"},{"attributes":{"plot":null,"text":"Markowitz Bullet for Portfolio with the minimum volatility of 0.0095, annualized returns of 196.72%, and Sharpe ratio of 0.0738"},"id":"b738c466-9fed-4eb6-8c33-6a43f1070099","type":"Title"},{"attributes":{"below":[{"id":"988ecefa-c36d-495a-b08c-38f0b95d3e68","type":"LinearAxis"}],"left":[{"id":"9c95d56d-9d50-41d6-a5de-86285ac64c9f","type":"LinearAxis"}],"plot_width":980,"renderers":[{"id":"988ecefa-c36d-495a-b08c-38f0b95d3e68","type":"LinearAxis"},{"id":"d01c16d0-84f9-4366-99db-17ba85b4b46b","type":"Grid"},{"id":"9c95d56d-9d50-41d6-a5de-86285ac64c9f","type":"LinearAxis"},{"id":"0eeb097e-1d58-47e4-a7f4-5d9be29bbeb6","type":"Grid"},{"id":"3d498590-69fa-484b-a4c6-8d35cb4c2adf","type":"BoxAnnotation"},{"id":"fe5a30d4-c331-44cf-8b18-1f1f5488afb0","type":"GlyphRenderer"},{"id":"d348fae9-312c-46d5-979c-02ca4a153285","type":"GlyphRenderer"},{"id":"0eb55ce1-9f8a-4bea-bc26-599b5fc00496","type":"GlyphRenderer"}],"title":{"id":"b738c466-9fed-4eb6-8c33-6a43f1070099","type":"Title"},"toolbar":{"id":"516fcfa4-b40c-4cdb-a658-4914d951119d","type":"Toolbar"},"x_range":{"id":"332f3c23-b811-4286-9c00-c32aa001d091","type":"DataRange1d"},"x_scale":{"id":"78e6326d-b0ef-4ad5-a866-05c9cfb2c22e","type":"LinearScale"},"y_range":{"id":"9376a0aa-fe88-437f-9056-f6082dee55f9","type":"DataRange1d"},"y_scale":{"id":"8bc7ba4c-bc5b-4754-ba0b-6ed0dcfc012b","type":"LinearScale"}},"id":"ac8f8012-ac7a-4998-bda8-f21ecb01a939","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[10000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[10000]}}},"id":"9aa5d4ed-b067-4c4d-8b85-cead052ccf01","type":"ColumnDataSource"},{"attributes":{},"id":"0ae9b365-b2b3-4450-8b84-53917f9e8e1d","type":"BasicTicker"},{"attributes":{"plot":{"id":"ac8f8012-ac7a-4998-bda8-f21ecb01a939","subtype":"Figure","type":"Plot"},"ticker":{"id":"0ae9b365-b2b3-4450-8b84-53917f9e8e1d","type":"BasicTicker"}},"id":"d01c16d0-84f9-4366-99db-17ba85b4b46b","type":"Grid"},{"attributes":{"axis_label":"Volatility","formatter":{"id":"14f6a8a6-fb63-42ec-98c7-7b40ba50e03a","type":"BasicTickFormatter"},"plot":{"id":"ac8f8012-ac7a-4998-bda8-f21ecb01a939","subtype":"Figure","type":"Plot"},"ticker":{"id":"0ae9b365-b2b3-4450-8b84-53917f9e8e1d","type":"BasicTicker"}},"id":"988ecefa-c36d-495a-b08c-38f0b95d3e68","type":"LinearAxis"},{"attributes":{"callback":null},"id":"9376a0aa-fe88-437f-9056-f6082dee55f9","type":"DataRange1d"},{"attributes":{"source":{"id":"766bd9ff-60e4-46dd-a227-eeda401a5331","type":"ColumnDataSource"}},"id":"14ac61af-affc-4c87-aaee-169092d8e119","type":"CDSView"},{"attributes":{},"id":"8bc7ba4c-bc5b-47 ...

# %% [markdown]
# ## E. Efficient Portfolio for the highest daily returns

# %%
def getReturns(mix):
    return( -PORTFOLIO(mix)[0] )

# %%
from scipy.optimize import minimize

x0 = np.ones(len(tickers))  


cons = ({'type': 'eq', 'fun': lambda x:  sum(x) - 1})  # MIX SHOULD ADD TO ONE i.e. 'sum(x) = 1' -> 'sum(x) - 1 = 0'


bnds = tuple((0.0, 1.0) for x in x0)  # NO SHORT... ALL VALUES POSITIVE BETWEEN 0 AND 1
#bnds = tuple((-1.0, 1.0) for x in x0)  # ALLOW SHORT... ALL VALUES BETWEEN -1 AND 1

OPT_RETURNS = minimize(getReturns, x0, method='SLSQP', bounds=bnds, constraints=cons, options={'disp': True, 'ftol': 1e-8})


print( "Highest Daily Returns {}".format( np.round(-OPT_RETURNS.fun, 4) ) )
OPT_RETURNS_MIX = pd.DataFrame(np.round( OPT_RETURNS.x * 100, 2 ), index=RETURNS.columns, columns=['Percent of Portfolio'])
OPT_RETURNS_MIX
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -0.004599598738863646
#             Iterations: 27
#             Function evaluations: 270
#             Gradient evaluations: 27
# Highest Daily Returns 0.0046
#       Percent of Portfolio
# BA                     0.0
# LRCX                   0.0
# NVDA                 100.0
# OLED                   0.0
# SOXL                   0.0
# SQ                     0.0
# TTD                    0.0
# TTWO                   0.0

# %%
target_return_mean , target_return_std , target_return_sharpe , target_return_annualized = PORTFOLIO( OPT_RETURNS.x ) 
print( 'Markowitz Bullet for Portfolio with maximum daily returns of {0}, sigma of {1}, and Sharpe ratio {2}'.\
           format(np.round(target_return_mean,4) , np.round(target_return_std,4) , np.round(target_return_sharpe,5) ) )
# Out:
# Markowitz Bullet for Portfolio with maximum daily returns of 0.0046, sigma of 0.0327, and Sharpe ratio 0.07084

# %%
p = figure( title = 'Markowitz Bullet for Portfolio with maximum annual returns of {0}%, sigma of {1}, and Sharpe ratio {2}'.\
           format(np.round(target_return_annualized,2) , np.round(target_return_std,4) , np.round(target_return_sharpe,4) ) , 
           plot_width=980  )
p.xaxis.axis_label = 'Volatility'
p.yaxis.axis_label = 'Daily Returns'
 
p.circle(x=stds, y=means, fill_alpha=0.2, size=2 )
p.line(x=frontier_var, y=frontier_mean, line_width=2, color='gold')
p.circle(x=target_return_std, y=target_return_mean, fill_alpha=0.77 , size=14 , color='red' )
p.toolbar.active_drag = None
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8b775fa0-3e66-46c1-94e8-04bf81a7ac70"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("8b775fa0-3e66-46c1-94e8-04bf81a7ac70");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8b775fa0-3e66-46c1-94e8-04bf81a7ac70");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8b775fa0-3e66-46c1-94e8-04bf81a7ac70' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"11a79f38-bfb2-442c-90e5-dc1dca3b4636":{"roots":{"references":[{"attributes":{},"id":"6d82a888-b3e5-48f2-aa8d-467143477a29","type":"HelpTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"3a9608d2-5111-440a-b3d0-c8bd68e76bf8","type":"Circle"},{"attributes":{},"id":"a9f04ce5-c780-4a6a-8211-22bbc58cbb3b","type":"SaveTool"},{"attributes":{"source":{"id":"5b302c29-6320-4a50-86a8-63dfdcde1669","type":"ColumnDataSource"}},"id":"7820e717-7a6f-4dfe-9fe9-63ab9ee5a7dc","type":"CDSView"},{"attributes":{},"id":"f2b0595f-ea46-4d0f-9d58-8ef37bb78a25","type":"PanTool"},{"attributes":{"axis_label":"Volatility","formatter":{"id":"8b72e671-a104-49d6-ae33-321d6225f2af","type":"BasicTickFormatter"},"plot":{"id":"ac297a79-59ed-48eb-bb37-dc75d718ab56","subtype":"Figure","type":"Plot"},"ticker":{"id":"da01e3e3-cc6e-4f05-960e-18b4427a4518","type":"BasicTicker"}},"id":"260a8697-d104-4cb1-ac2a-2ba634c7ddca","type":"LinearAxis"},{"attributes":{"callback":null},"id":"a5530705-d779-4af4-a78c-9d734e6ea90a","type":"DataRange1d"},{"attributes":{"below":[{"id":"260a8697-d104-4cb1-ac2a-2ba634c7ddca","type":"LinearAxis"}],"left":[{"id":"0922c523-6bcb-49cb-9f09-4a536fcc4e64","type":"LinearAxis"}],"plot_width":980,"renderers":[{"id":"260a8697-d104-4cb1-ac2a-2ba634c7ddca","type":"LinearAxis"},{"id":"f694974d-bdb1-4725-a46c-e99550f7196c","type":"Grid"},{"id":"0922c523-6bcb-49cb-9f09-4a536fcc4e64","type":"LinearAxis"},{"id":"acef5542-a8b0-486f-a2db-0c3bd2121d35","type":"Grid"},{"id":"376a963a-317d-420c-b8a3-fb94ecf58477","type":"BoxAnnotation"},{"id":"1b3d2013-5f62-45ac-ab01-29a4dc7cd009","type":"GlyphRenderer"},{"id":"2a393166-44d3-4858-90e0-00cf8bd9df67","type":"GlyphRenderer"},{"id":"46822181-5347-4724-923f-a38bca28663d","type":"GlyphRenderer"}],"title":{"id":"ead7f2b5-1528-4a0c-8cd6-11a184732834","type":"Title"},"toolbar":{"id":"3a7c8cb2-e9e0-4583-901a-b99236c43be5","type":"Toolbar"},"x_range":{"id":"60db6d79-c884-49de-9449-7c42513a816f","type":"DataRange1d"},"x_scale":{"id":"9fd1bc44-54b5-414f-817b-a60e6fbdf253","type":"LinearScale"},"y_range":{"id":"a5530705-d779-4af4-a78c-9d734e6ea90a","type":"DataRange1d"},"y_scale":{"id":"084cbcae-ac39-4d00-b4ec-4d9d57a5f2ce","type":"LinearScale"}},"id":"ac297a79-59ed-48eb-bb37-dc75d718ab56","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[10000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[10000]}}},"id":"5b302c29-6320-4a50-86a8-63dfdcde1669","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"a545a255-c2e9-40ab-a22a-76d14f654726","type":"ColumnDataSource"},"glyph":{"id":"e86e6193-d7ec-4c79-9ebb-1d4edc89e4b5","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3b9819ac-669f-46d9-b75b-20a39956b71c","type":"Circle"},"selection_glyph":null,"view":{"id":"1a491336-7ddb-40f0-b188-36b06f7469a6","type":"CDSView"}},"id":"46822181-5347-4724-923f-a38bca28663d","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.77},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":14},"x":{"value":0.032682651023492895},"y":{"value":0.004599598738863646}},"id":"e86e6193-d7ec-4c79-9ebb-1d4edc89e4b5","type":"Circle"},{"attributes":{"line_color":{"value":"gold"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"77e4df92-dc3e-4945-b9f0-5a46a8707bcc","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"ac297a79-59ed-48eb-bb37-dc75d718ab56","subtype":"Figure","type":"Plot"},"ticker":{"id":"30c99ea3-574f-4659-a46b-6541560a1657","type":"BasicTicker"}},"id":"acef5542-a8b0-486f-a2db-0c3bd2121d35","type":"Grid"},{"attributes":{},"id":"084cbcae-ac39-4d00-b4ec-4d9d57a5f2ce","type":"LinearScale"},{"attributes":{},"id":"8b72e671-a104-49d6-ae33-321d62 ...

# %% [markdown]
# ## F. Optimum Sharpe Ratio
#
# http://www.investopedia.com/terms/s/sharperatio.asp

# %% [markdown]
# The **Scipy minimize** function will need a function with one objective (-Sharpe ratio).  The **getSharpe** function wraps the **PORTFOLIO** function and only returns the Sharpe ratio.

# %%
def getSharpe(mix):
    return( -PORTFOLIO(mix)[2] )

# %%
from scipy.optimize import minimize


x0 = np.ones(len(tickers)) 


cons = ({'type': 'eq', 'fun': lambda x:  sum(x) - 1})  # MIX SHOULD ADD TO ONE i.e. 'sum(x) = 1' -> 'sum(x) - 1 = 0'


bnds = tuple((0.0, 1.0) for x in x0)  # NO SHORT... ALL VALUES POSITIVE BETWEEN 0 AND 1
#bnds = tuple((-1.0, 1.0) for x in x0)  # ALLOW SHORT... ALL VALUES POSITIVE BETWEEN 0 AND 1

OPT_SHARPE = minimize(getSharpe, x0, method='SLSQP', bounds=bnds, constraints=cons, options={'disp': True, 'ftol': 1e-8})


print( "Highest Sharpe Ratio {}".format( np.round(-OPT_SHARPE.fun, 4) ) )
OPT_SHARPE_MIX = pd.DataFrame(np.round( OPT_SHARPE.x * 100, 2 ), index=RETURNS.columns, columns=['Percent of Portfolio'])
OPT_SHARPE_MIX
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -0.10514039241803558
#             Iterations: 12
#             Function evaluations: 121
#             Gradient evaluations: 12
# Highest Sharpe Ratio 0.1051
#       Percent of Portfolio
# BA                   29.02
# LRCX                  0.00
# NVDA                 16.92
# OLED                  4.14
# SOXL                  0.00
# SQ                   28.73
# TTD                   3.72
# TTWO                 17.47

# %%
best_sharpe_return , best_sharpe_std , best_sharpe , best_sharpe_annualized_return = PORTFOLIO( OPT_SHARPE.x.T ) 
print('Markowitz Bullet for Portfolio with maximum Sharpe ratio of {2}, return of {0}, and sigma of {1}'.\
           format(np.round(best_sharpe_return,4) , np.round(best_sharpe_std,4) , np.round(best_sharpe,4)) )
# Out:
# Markowitz Bullet for Portfolio with maximum Sharpe ratio of 0.1051, return of 0.0036, and sigma of 0.0124

# %%
p = figure( title = 'Markowitz Bullet for Portfolio with maximum Sharpe ratio of {2}, annualized returns of {0}%, and sigma of {1}'.\
           format(np.round(best_sharpe_annualized_return,2) , np.round(best_sharpe_std,4) , np.round(best_sharpe,4) ) , 
           plot_width=980  )
p.xaxis.axis_label = 'Volatility'
p.yaxis.axis_label = 'Daily Returns'
 
p.circle(x=stds, y=means, fill_alpha=0.2, size=2 )
p.line(x=frontier_var, y=frontier_mean, line_width=2, color='gold')
p.circle(x=best_sharpe_std, y=best_sharpe_return, fill_alpha=0.77 , size=14 , color='red' )
p.toolbar.active_drag = None
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0678223b-3002-433f-9478-1fedd3e6c51b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("0678223b-3002-433f-9478-1fedd3e6c51b");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0678223b-3002-433f-9478-1fedd3e6c51b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0678223b-3002-433f-9478-1fedd3e6c51b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c10b8356-4975-452f-b6c2-11b2ed69c91e":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[10000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[10000]}}},"id":"f9fa4438-55bf-4dc6-9a81-9d4463f2d403","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.011365051197412285,0.009918873756969473,0.009767414168454915,0.00962630900700771,0.009546951695875642,0.00950437206664317,0.009498461035548217,0.009503946674323529,0.009537168929271127,0.009588866862647982,0.009670081193522,0.009773705912017473,0.009886492028254269,0.01004106691007858,0.010199815097816886,0.010393781238589157,0.010617330823576424,0.010863988274540394,0.011133217248293732,0.011425957253034935,0.011761436071154754,0.012087172804068727,0.012420915490619822,0.012787103660778294,0.013161488803086114,0.013546803246965968,0.013946975335786267,0.014363981437454631,0.01478247254659464,0.015215979860252155,0.015656420754672263,0.01610459324751199,0.016562418882457686,0.017025073721268675,0.01750880947611272,0.018035052023399716,0.018600892094669787,0.01918530742565932,0.019822641177077955,0.020555811097823555,0.021376512957078306,0.022304910920879852,0.023315326781781345,0.024409516061668895,0.02557847366788678,0.026822937536951575,0.0281407274402156,0.029495065379181937,0.030907319410461234,0.032682651023485124],"y":[0.002766667611369863,0.0028040743431855973,0.002841481112348007,0.0028788878350759495,0.0029162946103784898,0.0029537013669711713,0.002991108122445518,0.0030285148941069815,0.003065921642508836,0.0031033284126335925,0.003140735144311088,0.0031781419011584593,0.003215548701591469,0.003252955459814938,0.0032903621778957023,0.0033277689406934824,0.00336517572666318,0.0034025824573316633,0.003439989239488617,0.00347739596780163,0.0035148027420422324,0.0035522094744871893,0.0035896162570966585,0.003627023018375128,0.003664429790433441,0.003701836535783957,0.0037392433007170534,0.0037766500357823297,0.003814056825929976,0.0038514635527372738,0.00388887031662702,0.003926277082533229,0.00396368381715866,0.004001090595901744,0.004038497337216924,0.004075904115603373,0.004113310858828461,0.004150717631602271,0.004188124395881538,0.0042255311366713,0.004262937874121222,0.004300344660344488,0.004337751400454986,0.0043751581880524274,0.0044125649018862114,0.004449971682661612,0.004487378447800781,0.004524785218624389,0.004562191954100434,0.004599598738863536]}},"id":"a49c2a59-22fb-496f-b621-87c418a82dd7","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"a49c2a59-22fb-496f-b621-87c418a82dd7","type":"ColumnDataSource"},"glyph":{"id":"4ed3699d-b435-4a9f-9f05-2c3828deb220","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c744f46e-f78c-4674-9442-7e24cbb39f72","type":"Line"},"selection_glyph":null,"view":{"id":"790a88b9-b59f-4c65-a6e7-5b2e31dcf152","type":"CDSView"}},"id":"f95e3e1f-9a14-4c5e-85f6-5d39a356140c","type":"GlyphRenderer"},{"attributes":{},"id":"e7aa8fe7-cdee-4141-a62e-f990567d1b7a","type":"SaveTool"},{"attributes":{"active_drag":null,"active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"43188ba4-e551-4205-8f91-ca9faae83193","type":"PanTool"},{"id":"be494fa1-c8bf-455f-9e59-d0c207d4cdf9","type":"WheelZoomTool"},{"id":"c3008b25-d806-45d3-9ea8-deb7b3e7d88e","type":"BoxZoomTool"},{"id":"e7aa8fe7-cdee-4141-a62e-f990567d1b7a","type":"SaveTool"},{"id":"b589fa35-c3d0-496b-9c99-b28cb1e052ed","type":"ResetTool"},{"id":"0f7bd8a2-8a81-45ef-8197-d679f674ee34","type":"HelpTool"}]},"id":"773b6d45-63c0-4585-bd2a-07b6fbd4bcaa","type":"Toolbar"},{"attributes":{},"id":"5f159fd3-7c5f-4c93-9bad-a652d7ec208c","type":"LinearScale"},{"attributes":{"source":{"id":"a49c2a59-22fb-496f-b621-87c418a82dd7","type":"ColumnDataSource"}},"id":"790a88b9-b59f-4c65-a6e7-5b2e31dcf152","type":"CDSView"},{"attributes":{"callback":null},"id":"8578e0d2-73b1-4b61-b801-88b ...
